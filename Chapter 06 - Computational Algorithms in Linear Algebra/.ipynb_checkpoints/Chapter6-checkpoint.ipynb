# %% [markdown]
# # Chapter 6 - Computational Algorithms in Linear Algebra
#
# This notebook contains code accompanying Chapter 6 Computational Algorithms in Linear Algebra in *Practical Discrete Mathematics* by Ryan T. White and Archana Tikayat Ray.
#
# ## Matrices and Matrix Representations of Linear Systems
#
# The code below stores matrices as `NumPy` arrays and prints specified entries of the matrices.

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# Step 1: URL of the image (You can replace this URL with any valid image URL)
image_url = 'https://images.pexels.com/photos/610293/pexels-photo-610293.jpeg'

# Step 2: Fetch the image using a GET request
response = requests.get(image_url)

# Step 3: Check if the request was successful (status code 200)
if response.status_code == 200:
    # Step 4: Open the image from the response content
    img = Image.open(BytesIO(response.content))

    # Step 5: Transpose (rotate) the image by 90 degrees
    transposed_img = img.transpose(Image.ROTATE_90)

    # Step 6: Display the transposed image
    plt.imshow(transposed_img)
    plt.axis('off')  # Hide axis for better display
    plt.show()
else:
    print("Failed to retrieve the image.")

# %%
# Install necessary libraries
# !pip install requests Pillow matplotlib

import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt

# Step 1: Fetch image from a Creative Commons Wikipedia page
image_url = 'https://images.pexels.com/photos/610293/pexels-photo-610293.jpeg'

# Send a GET request to download the image
response = requests.get(image_url)

# Check if the request was successful
if response.status_code == 200:
    # Step 2: Open the image from the response content
    img = Image.open(BytesIO(response.content))

    # Step 3: Enlarge the image to double its size
    width, height = img.size
    new_size = (width * 2, height * 2)
    enlarged_img = img.resize(new_size)

    # Step 4: Display the enlarged image using matplotlib
    plt.figure(figsize=(8,8))
    plt.imshow(enlarged_img)
    plt.axis('off')  # Hide axes
    plt.show()
else:
    print("Failed to retrieve the image.")

# %%
# Step 1: Install the rembg and onnxruntime libraries
# !pip install rembg pillow onnxruntime

# Step 2: Import necessary libraries
from rembg import remove
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# Step 3: Download the image
image_url = "https://vignette.wikia.nocookie.net/gameofthrones/images/2/25/707_Daenerys_Profil.jpg/revision/latest?cb=20170829215522&path-prefix=de"
response = requests.get(image_url)
image = Image.open(BytesIO(response.content))

# Step 4: Remove the background
input_image = BytesIO()
image.save(input_image, format="PNG")
input_image.seek(0)

output_image = remove(input_image.read())

# Convert the result back to an image
result_image = Image.open(BytesIO(output_image))

# Step 5: Display the original and processed images
plt.figure(figsize=(12, 6))

# Display original image
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title("Original Image")
plt.axis("off")

# Display image with background removed
plt.subplot(1, 2, 2)
plt.imshow(result_image)
plt.title("Image with Background Removed")
plt.axis("off")

# Show both images
plt.show() # Added parentheses to call the show function
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 89.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.7 MB/s eta 0:00:00
# ...
# 100%|███████████████████████████████████████| 176M/176M [00:00<00:00, 81.9GB/s]

# %%
# Import necessary libraries
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# Step 1: Define the URL of the image
image_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/2014_Rallye_Deutschland_by_2eight_8SC0443.jpg/800px-2014_Rallye_Deutschland_by_2eight_8SC0443.jpg"

# Step 2: Load the image from the URL
response = requests.get(image_url)
image = Image.open(BytesIO(response.content))

# Step 3: Convert the image to grayscale
gray_image = image.convert("L")  # 'L' mode is for grayscale

# Step 4: Display the grayscale image
plt.figure(figsize=(8, 8))
plt.imshow(gray_image, cmap='gray')  # Use 'gray' colormap for proper grayscale display
plt.title("Grayscale Image")
plt.axis("off")  # Hide axes for better viewing
plt.show()

# Optional: Save the grayscale image
gray_image.save("grayscale_image.jpg", "JPEG")
print("Grayscale image saved as 'grayscale_image.jpg'")
# Out:
# Grayscale image saved as 'grayscale_image.jpg'

# %%
# !pip install pillow

from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt

# Load the images
url1 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e0/2014_Rallye_Deutschland_by_2eight_8SC0443.jpg/800px-2014_Rallye_Deutschland_by_2eight_8SC0443.jpg'  # First image URL
url2 = 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/The_Empire_Hotel_06.jpg/1280px-The_Empire_Hotel_06.jpg'  # Second image URL

response1 = requests.get(url1)
img1 = Image.open(BytesIO(response1.content))

response2 = requests.get(url2)
img2 = Image.open(BytesIO(response2.content))

# Display the original images
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.imshow(img1)
plt.title('Image 1')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(img2)
plt.title('Image 2')
plt.axis('off')

plt.show()

# Combine the images vertically
width = max(img1.width, img2.width)
total_height = img1.height + img2.height

combined_img = Image.new('RGB', (width, total_height))
combined_img.paste(img1, (0, 0))
combined_img.paste(img2, (0, img1.height))

# Display the combined image
plt.imshow(combined_img)
plt.title('Combined Image')
plt.axis('off')
plt.show()

# %%
import numpy

# initialize matrices
A = numpy.array([[3, 2, 1], [9, 0, 1], [3, 4, 1]])
B = numpy.array([[1, 1, 2], [8, 4, 1], [0, 0, 3]])

# print the entry in the first row and first column of A
print(A[0,0])

# print the entry in the second row and third column of B
print(B[1,2])
# Out:
# 3
# 1

# %% [markdown]
# ### Example: Matrix Addition and Subtraction

# %%
# Add A and B
print(numpy.add(A,B))

# Subtract A and B
print(numpy.subtract(A,B))
# Out:
# [[ 4  3  3]
#  [17  4  2]
#  [ 3  4  4]]
# [[ 2  1 -1]
#  [ 1 -4  0]
#  [ 3  4 -2]]

# %% [markdown]
# ### Example: Scalar Multiplication and Transpose

# %%
# Multiply A by a scalar 5
print(numpy.multiply(5,A))

# Find the transpose of A
print(numpy.transpose(A))
# Out:
# [[15 10  5]
#  [45  0  5]
#  [15 20  5]]
# [[3 9 3]
#  [2 0 4]
#  [1 1 1]]

# %% [markdown]
# ### Example: Matrix Multiplication and Transpose

# %%
# Multiply A and B
print(numpy.dot(A,B))
# Out:
# [[19 11 11]
#  [ 9  9 21]
#  [35 19 13]]

# %% [markdown]
# ## Solving Large Linear Systems with `NumPy`
#
# ### Example: Solving $\mathbf{Ax}=\mathbf{b}$ for $\mathbf{x}$

# %%
import numpy

# Create A and b matrices
A = numpy.array([[2, -6, 6], [2, 3, -1], [4, -3, -1]])
b = numpy.array([-8, 15, 19])

# Solve Ax = b
numpy.linalg.solve(A,b)
# Out:
# array([ 5.,  1., -2.])

# %% [markdown]
# ### Example: Inconsistent and Dependent Systems with `NumPy`

# %%
import numpy

# inconsistent system
A = numpy.array([[2, 1], [6, 3]])
b = numpy.array([3, 3])

print(numpy.linalg.solve(A,b))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-14-88a6688b74fc> in <module>
#       5 b = numpy.array([3, 3])
#       6
# ----> 7 print(numpy.linalg.solve(A,b))
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# ...

# %% [markdown]
# Note that the code throws an error because the matrix $\mathbf{A}$ is singular since the system is inconsistent--i.e. there are no solutions.

# %%
# dependent system
A = numpy.array([[2, 1], [6, 3]])
b = numpy.array([1, 3])

print(numpy.linalg.solve(A,b))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-19-a7825dde56f3> in <module>
#       3 b = numpy.array([1, 3])
#       4
# ----> 5 print(numpy.linalg.solve(A,b))
#
# <__array_function__ internals> in solve(*args, **kwargs)
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in solve(a, b)
#     392     signature = 'DD->D' if isComplexType(t) else 'dd->d'
#     393     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 394     r = gufunc(a, b, signature=signature, extobj=extobj)
#     395
#     396     return wrap(r.astype(result_t, copy=False))
#
# ~\anaconda3\envs\DL\lib\site-packages\numpy\linalg\linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
#      90 def _raise_linalgerror_nonposdef(err, flag):
#
# ...

# %% [markdown]
# Note that the code throws an error because the matrix $\mathbf{A}$ is singular since the system is dependent--i.e. there are infinitely many solutions, as we can confirm below.

# %%
A = numpy.array([[2, 1], [6, 3]])
print(numpy.linalg.det(A))
# Out:
# 0.0

# %% [markdown]
# ### Example: 10-by-10 Linear System (with `NumPy`)

# %%
import numpy

numpy.random.seed(1)

# Create A and b matrices with random
A = 10*numpy.random.rand(10,10)-5
b = 10*numpy.random.rand(10)-5

# Solve Ax = b
solution = numpy.linalg.solve(A,b)
print(solution)

# To verify the solution works, show Ax - b is near 0
sum(abs(numpy.dot(A,solution) - b))
# Out:
# [ 0.09118027 -1.51451319 -2.48186344 -2.94076307  0.07912968  2.76425416
#   2.48851394 -0.30974375 -1.97943716  0.75619575]
# 2.1538326677728037e-14
